# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:/Users/user/Desktop/경기도 빅데이터 자료/화이팅하조 팀프로젝트/Z_FORESTON_ROAD_CLIMB4.xlsx")

# %%
df.head()
# Out:
#        산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도  시작_표고  끝_표고값  \
# 0  2607102100  26071021000036  21755    422    296     1.0  680.0  664.0
# 1  2818101300  28181013000023  16640    323    226     1.0  756.0  766.0
# 2  2807093800  28070938000001  15399    299    209     1.0  661.0  540.0
# 3  2413993300  24139933000007  14689    285    200     1.0  523.0  517.0
# 4  2309010200  23090102000015  12629    245    172     1.0  239.0  231.0
#
#      고도차       경사도  Unnamed: 10
# 0   16.0  0.073546          NaN
# 1   10.0  0.060096          NaN
# 2  121.0  0.785765          NaN
# 3    6.0  0.040847          NaN
# 4    8.0  0.063346          NaN

# %%
df = df.drop('Unnamed: 10',1)

# %%
df.head(10)
# Out:
#        산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값  \
# 0  2607102100  26071021000036  21755    422    296     1.0   680.0   664.0
# 1  2818101300  28181013000023  16640    323    226     1.0   756.0   766.0
# 2  2807093800  28070938000001  15399    299    209     1.0   661.0   540.0
# 3  2413993300  24139933000007  14689    285    200     1.0   523.0   517.0
# 4  2309010200  23090102000015  12629    245    172     1.0   239.0   231.0
# 5  2709174400  27091744000001  10761    209    146     1.0   929.0   746.0
# 6  2812140300  28121403000007  10627    206    144     2.0   571.0   561.0
# 7  2210021800  22100218000006  10296    200    140     2.0  1107.0  1097.0
# 8  2817121200  28171212000006   9730    219    153     1.0    16.0  1084.0
# 9  2101992500  21019925000027   9621    187    131     1.0   628.0   310.0
#
#       고도차        경사도
# 0    16.0   0.073546
# 1    10.0   0.060096
# 2   121.0   0.785765
# 3     6.0   0.040847
# 4     8.0   0.063346
# ...

# %%
df = df.dropna()

# %%
df.head()
# Out:
#        산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도  시작_표고  끝_표고값  \
# 0  2607102100  26071021000036  21755    422    296     1.0  680.0  664.0
# 1  2818101300  28181013000023  16640    323    226     1.0  756.0  766.0
# 2  2807093800  28070938000001  15399    299    209     1.0  661.0  540.0
# 3  2413993300  24139933000007  14689    285    200     1.0  523.0  517.0
# 4  2309010200  23090102000015  12629    245    172     1.0  239.0  231.0
#
#      고도차       경사도
# 0   16.0  0.073546
# 1   10.0  0.060096
# 2  121.0  0.785765
# 3    6.0  0.040847
# 4    8.0  0.063346

# %%
col_idx = ['구간_거리','구간_하행','시작_표고','끝_표고값']

# %%
train = df[col_idx]

# %%
train
# Out:
#        구간_거리  구간_하행   시작_표고   끝_표고값
# 0      21755    296   680.0   664.0
# 1      16640    226   756.0   766.0
# 2      15399    209   661.0   540.0
# 3      14689    200   523.0   517.0
# 4      12629    172   239.0   231.0
# 5      10761    146   929.0   746.0
# 6      10627    144   571.0   561.0
# 7      10296    140  1107.0  1097.0
# 8       9730    153    16.0  1084.0
# 9       9621    131   628.0   310.0
# 10      9523    129   363.0   275.0
# 11      9503    129   264.0   461.0
# 12      9251    126   641.0   460.0
# 13      9081    123   553.0   553.0
# 14      8619    117   471.0    20.0
# 15      8574    117   183.0   110.0
# 16      8229    112    18.0   470.0
# 17      8192    111    96.0   571.0
# 18      8192    111    13.0    96.0
# 19      8192    111   622.0   747.0
# 20      8192    111   571.0   622.0
# 21      8192    111   747.0   843.0
# 22      8076    127  1216.0    15.0
# 23      8063    110   264.0   277.0
# 24      8063    110   255.0   302.0
# ...

# %%
from sklearn.model_selection import train_test_split
x1, x2, y1, y2 = train_test_split(train,df.구간_상행,test_size=0.2 , random_state=42)

# %%
print(x1.shape)
print(x2.shape)
print(y1.shape)
print(y2.shape)
# Out:
# (16176, 4)
# (4044, 4)
# (16176,)
# (4044,)

# %%
train_model = DecisionTreeRegressor()

# %%
train_model.fit(x1,y1)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
print("Making predictions for the following 10 :")
print(x2)
print("The predictions are")
print(train_model.predict(x2))
# Out:
# Making predictions for the following 10 :
#        구간_거리  구간_하행  시작_표고   끝_표고값
# 11167    222      3   83.0   115.0
# 3912     974     19  198.0    25.0
# 12717    164      5  260.0   308.0
# 11660    203      9  360.0   297.0
# 4153     921     23   84.0   308.0
# 8192     396      8  218.0   150.0
# 15682     82      1  145.0   155.0
# 5635     662     10  230.0   318.0
# 5903     626     10  211.0   142.0
# 16670     62      2   51.0    36.0
# 16599     63      3  865.0   841.0
# 4293     890     14  341.0   233.0
# 7139     490     12  230.0   120.0
# 18235     36      1   80.0    70.0
# 2412    1461     20  856.0   710.0
# 18843     27      1   82.0    79.0
# 11627    204      3  384.0   375.0
# 3844     990     16  231.0    93.0
# 2140    1598     22  394.0   235.0
# 15994     76      2  236.0   257.0
# 17693     44      1   70.0    61.0
# 16991     56      2  381.0   366.0
# 14008    122      2  110.0   109.0
# 6114     599     25  339.0   576.0
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred = train_model.predict(x2)
accuracy_score(y2,y_pred)
# Out:
# 0.8402571711177053

# %%
df1 = df[df.구간_난이도==3]

# %%
df1
# Out:
#            산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고  \
# 287    2603070100  26030701000007   3959     77     54     3.0   540.0
# 302    2802042000  28020420000002   3888     87     61     3.0   833.0
# 327    2305071900  23050719000003   3816     86     60     3.0   547.0
# 344    2802011100  28020111000033   3746     73     51     3.0   996.0
# 361    2802011100  28020111000034   3691     72     50     3.0   976.0
# 381    1704041600  17040416000015   3645     82     57     3.0   580.0
# 389    2820073800  28200738000003   3622    101     71     3.0  1112.0
# 397    2807052000  28070520000004   3589     70     49     3.0   314.0
# 416    2702470100  27024701000021   3530     69     48     3.0   200.0
# 420    2599990500  25999905000063   3516     68     48     3.0   263.0
# 427    2107111300  21071113000007   3496     68     48     3.0   298.0
# 446    1704060100  17040601000011   3420     77     54     3.0   725.0
# ...

# %%
train1 = df1[col_idx]

# %%
train1
# Out:
#        구간_거리  구간_하행   시작_표고   끝_표고값
# 287     3959     54   540.0   710.0
# 302     3888     61   833.0   381.0
# 327     3816     60   547.0   118.0
# 344     3746     51   996.0   976.0
# 361     3691     50   976.0  1156.0
# 381     3645     57   580.0   157.0
# 389     3622     71  1112.0   414.0
# 397     3589     49   314.0    26.0
# 416     3530     48   200.0   130.0
# 420     3516     48   263.0    45.0
# 427     3496     48   298.0    73.0
# 446     3420     54   725.0   230.0
# 448     3419     46   109.0   270.0
# 452     3413     46   361.0    39.0
# 464     3394      1   766.0   524.0
# 467     3383     66   864.0   253.0
# 476     3358     46   492.0   556.0
# 490     3331     65   557.0  1113.0
# 503     3307     52   575.0   156.0
# 508     3298     52    92.0   500.0
# 511     3297     81  1072.0   412.0
# 516     3285     45   725.0   957.0
# 525     3272     80  1164.0   466.0
# 526     3264     51   877.0   489.0
# 527     3263     64   664.0    66.0
# ...

# %%
x1,x2,y1,y2 = train_test_split(train1,df1.구간_상행,test_size=0.2 , random_state=42)

# %%
train_model1 = DecisionTreeRegressor()

# %%
train_model1.fit(x1,y1)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred1 = train_model.predict(x2)
accuracy_score(y2,y_pred1)
# Out:
# 0.968528494471222

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df1.구간_상행, df1.구간_하행)

# %%
df2 = df[df.구간_난이도==2]

# %%
plt.plot(df2.구간_상행,df2.구간_하행)

# %%
df3 = df[df.구간_난이도==1]

# %%
plt.plot(df3.구간_상행,df3.구간_하행)

# %%
plt.plot(df.구간_상행,df.구간_하행)

# %%
df.corr()
# Out:
#           산코드_번호     구간_일련     구간_거리     구간_상행     구간_하행    구간_난이도     시작_표고  \
# 산코드_번호  1.000000  0.999242  0.200507  0.214953  0.214401 -0.107248  0.223085
# 구간_일련   0.999242  1.000000  0.199452  0.214050  0.213499 -0.106975  0.222439
# 구간_거리   0.200507  0.199452  1.000000  0.921518  0.921517 -0.409141  0.240984
# 구간_상행   0.214953  0.214050  0.921518  1.000000  0.999786 -0.452667  0.282793
# 구간_하행   0.214401  0.213499  0.921517  0.999786  1.000000 -0.452670  0.282722
# 구간_난이도 -0.107248 -0.106975 -0.409141 -0.452667 -0.452670  1.000000 -0.276566
# 시작_표고   0.223085  0.222439  0.240984  0.282793  0.282722 -0.276566  1.000000
# 끝_표고값   0.222858  0.222586  0.228727  0.276476  0.276390 -0.270605  0.819755
# 고도차     0.192838  0.192155  0.715721  0.885411  0.885249 -0.410743  0.272874
# 경사도    -0.029726 -0.029690 -0.026381  0.003400  0.003508 -0.016707 -0.010630
#
#            끝_표고값       고도차       경사도
# 산코드_번호  0.222858  0.192838 -0.029726
# 구간_일련   0.222586  0.192155 -0.029690
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols, glm
import scipy as sp

my_fml = '구간_하행 ~ 구간_상행'
lm = ols(my_fml, data = df).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  구간_하행   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.725e+07
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        14:39:54   Log-Likelihood:                -7253.1
# No. Observations:               20220   AIC:                         1.451e+04
# Df Residuals:                   20218   BIC:                         1.453e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0601      0.003     20.070      0.000       0.054       0.066
# ...

# %%
df['총시간'] = df.구간_상행 + df.구간_하행

# %%
df.columns
# Out:
# Index(['산코드_번호', '구간_일련', '구간_거리', '구간_상행', '구간_하행', '구간_난이도', '시작_표고',
#        '끝_표고값', '고도차', '경사도', '총시간'],
#       dtype='object')

# %%
df.head(10)
# Out:
#        산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값  \
# 0  2607102100  26071021000036  21755    422    296     1.0   680.0   664.0
# 1  2818101300  28181013000023  16640    323    226     1.0   756.0   766.0
# 2  2807093800  28070938000001  15399    299    209     1.0   661.0   540.0
# 3  2413993300  24139933000007  14689    285    200     1.0   523.0   517.0
# 4  2309010200  23090102000015  12629    245    172     1.0   239.0   231.0
# 5  2709174400  27091744000001  10761    209    146     1.0   929.0   746.0
# 6  2812140300  28121403000007  10627    206    144     2.0   571.0   561.0
# 7  2210021800  22100218000006  10296    200    140     2.0  1107.0  1097.0
# 8  2817121200  28171212000006   9730    219    153     1.0    16.0  1084.0
# 9  2101992500  21019925000027   9621    187    131     1.0   628.0   310.0
#
#       고도차        경사도  총시간
# 0    16.0   0.073546  718
# 1    10.0   0.060096  549
# 2   121.0   0.785765  508
# 3     6.0   0.040847  485
# ...

# %%
df = df[['구간_거리','구간_상행','구간_하행','구간_난이도','시작_표고','끝_표고값','고도차','경사도','총시간']]

# %%
df.head(10)
# Out:
#    구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값     고도차        경사도  총시간
# 0  21755    422    296     1.0   680.0   664.0    16.0   0.073546  718
# 1  16640    323    226     1.0   756.0   766.0    10.0   0.060096  549
# 2  15399    299    209     1.0   661.0   540.0   121.0   0.785765  508
# 3  14689    285    200     1.0   523.0   517.0     6.0   0.040847  485
# 4  12629    245    172     1.0   239.0   231.0     8.0   0.063346  417
# 5  10761    209    146     1.0   929.0   746.0   183.0   1.700585  355
# 6  10627    206    144     2.0   571.0   561.0    10.0   0.094100  350
# 7  10296    200    140     2.0  1107.0  1097.0    10.0   0.097125  340
# 8   9730    219    153     1.0    16.0  1084.0  1068.0  10.976362  372
# 9   9621    187    131     1.0   628.0   310.0   318.0   3.305270  318

# %%
df['평균속력']=df.왕복거리 / df.총시간

# %%
df['왕복거리'] = df.구간_거리*2

# %%
df.head(10)
# Out:
#    구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값     고도차        경사도  총시간   왕복거리  \
# 0  21755    422    296     1.0   680.0   664.0    16.0   0.073546  718  43510
# 1  16640    323    226     1.0   756.0   766.0    10.0   0.060096  549  33280
# 2  15399    299    209     1.0   661.0   540.0   121.0   0.785765  508  30798
# 3  14689    285    200     1.0   523.0   517.0     6.0   0.040847  485  29378
# 4  12629    245    172     1.0   239.0   231.0     8.0   0.063346  417  25258
# 5  10761    209    146     1.0   929.0   746.0   183.0   1.700585  355  21522
# 6  10627    206    144     2.0   571.0   561.0    10.0   0.094100  350  21254
# 7  10296    200    140     2.0  1107.0  1097.0    10.0   0.097125  340  20592
# 8   9730    219    153     1.0    16.0  1084.0  1068.0  10.976362  372  19460
# 9   9621    187    131     1.0   628.0   310.0   318.0   3.305270  318  19242
#
#         평균속력
# 0  60.598886
# 1  60.619308
# 2  60.625984
# 3  60.573196
# 4  60.570743
# 5  60.625352
# ...

# %%
df
# Out:
#        구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값     고도차         경사도  총시간  \
# 0      21755    422    296     1.0   680.0   664.0    16.0    0.073546  718
# 1      16640    323    226     1.0   756.0   766.0    10.0    0.060096  549
# 2      15399    299    209     1.0   661.0   540.0   121.0    0.785765  508
# 3      14689    285    200     1.0   523.0   517.0     6.0    0.040847  485
# 4      12629    245    172     1.0   239.0   231.0     8.0    0.063346  417
# 5      10761    209    146     1.0   929.0   746.0   183.0    1.700585  355
# 6      10627    206    144     2.0   571.0   561.0    10.0    0.094100  350
# 7      10296    200    140     2.0  1107.0  1097.0    10.0    0.097125  340
# 8       9730    219    153     1.0    16.0  1084.0  1068.0   10.976362  372
# 9       9621    187    131     1.0   628.0   310.0   318.0    3.305270  318
# 10      9523    185    129     2.0   363.0   275.0    88.0    0.924079  314
# ...

# %%
plt.scatter(df.경사도[(df.경사도>=1.8)&(df.경사도<2)&(df.평균속력<55)], df.평균속력[(df.경사도>=1.8)&(df.경사도<2)&(df.평균속력<55)])

# %%
df[(df.경사도>=1.8)&(df.경사도<2)&(df.평균속력<55)]
# Out:
#            산코드_번호           구간_일련  구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고  \
# 14786  1203991300  12039913000022    102      3      2     3.0    99.0
# 17125  1404070100  14040701000146     54      1      1     3.0    83.0
# 17137  1407230600  14072306000110     54      1      1     3.0    68.0
# 17141  2204070300  22040703000003     54      1      1     3.0    22.0
# 17193  1408070100  14080701000101     53      1      1     3.0    26.0
# 17194  1601270100  16012701000233     53      1      1     3.0   165.0
# 17238  1404070100  14040701000331     52      1      1     3.0   183.0
# 17240  1704041602  17040416020070     52      1      1     3.0  1017.0
# 17242  2130022600  21300226000020     52      1      1     3.0   349.0
# 17252  1307060200  13070602000133     52      1      1     3.0    70.0
# 17253  1203991300  12039913000002     52      1      1     3.0   253.0
# 17254  1304461200  13044612000095     52      1      1     3.0   138.0
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.경사도[(df.경사도>=1)&(df.경사도<2)&(df.평균속력<100)], df.평균속력[(df.경사도>=1)&(df.경사도<2)&(df.평균속력<100)],
          df.구간_거리[(df.경사도>=1)&(df.경사도<2)&(df.평균속력<100)])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.경사도[(df.평균속력<70) & (df.경사도<1) & (df.경사도>0)], df.평균속력[(df.평균속력<70) & (df.경사도<1) & (df.경사도>0)], df.구간_거리[(df.평균속력<70) & (df.경사도<1) & (df.경사도>0)])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.경사도, df.평균속력, df.구간_거리)

# %%
plt.scatter(df.총시간, df.왕복거리)

# %%
# 시간과 거리 사이의 상관관계 파악
# 시간과 거리 데이터를 경사도에 따라서 나눈 후에 파악
from statsmodels.graphics.regressionplots import abline_plot

plot1 = plt.scatter(df.총시간[(df.경사도>=0)&(df.경사도<10)], df.왕복거리[(df.경사도>=0)&(df.경사도<10)],c='b')
plot2 = plt.scatter(df.총시간[(df.경사도>=10)&(df.경사도<15)], df.왕복거리[(df.경사도>=10)&(df.경사도<15)],c='r')
plot3 = plt.scatter(df.총시간[(df.경사도>=15)&(df.경사도<20)], df.왕복거리[(df.경사도>=15)&(df.경사도<20)],c='k')
plot4 = plt.scatter(df.총시간[(df.경사도>=20)&(df.경사도<25)], df.왕복거리[(df.경사도>=20)&(df.경사도<25)],c='g')
plot5 = plt.scatter(df.총시간[(df.경사도>=25)&(df.경사도<30)], df.왕복거리[(df.경사도>=25)&(df.경사도<30)],c='y')
plot6 = plt.scatter(df.총시간[df.경사도>=30], df.왕복거리[df.경사도>=30],c='m')

plt.legend((plot1,plot2,plot3,plot4,plot5,plot6), ('0 <= x < 10', '10 <= x < 15', '15 <= x < 20', '20 <= x < 25', '25 <= x < 30','x >= 30'),
           scatterpoints = 1, loc = 'lower right', ncol=1, fontsize=8)
plt.xlabel('TIME')
plt.ylabel('LEN')
plt.title('TIME~LEN')
# Out:
# Text(0.5,1,'TIME~LEN')

# %%
import seaborn as sns

# %%
# 경사도에 따른 회귀선 그래프
# 몇몇의 이상치를 재외하면 그래프가 특정한 선형을 이루는 것을 알 수 있다.

sns.regplot(x='총시간',y='왕복거리',data=df[(df.경사도>=0)&(df.경사도<10)])

sns.regplot(x='총시간',y='왕복거리',data=df[(df.경사도>=10)&(df.경사도<15)])

sns.regplot(x='총시간',y='왕복거리',data=df[(df.경사도>=15)&(df.경사도<20)])

sns.regplot(x='총시간',y='왕복거리',data=df[(df.경사도>=20)&(df.경사도<25)])

sns.regplot(x='총시간',y='왕복거리',data=df[(df.경사도>=25)&(df.경사도<30)])

sns.regplot(x='총시간',y='왕복거리',data=df[df.경사도>=30])

plt.legend(('0 <= x < 10', '10 <= x < 15', '15 <= x < 20', '20 <= x < 25', '25 <= x < 30','x >= 30'))
plt.title("TIME ~ LENGTH")
plt.xlabel("TIME")
plt.ylabel('LEN')

plt.savefig('총거리~왕복시간(경사도별)그래프.png')

# %%
# 총시간 ~ 왕복거리를 하면 0.849의 데이터를 이 그래프로 설명 가능하다
# 어느 정도 높은 숫자이긴 하지만 경사도로 세분화해서 처리하면 1에 더 가까운 결과를 처리 할 수 있다.

my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                 1.139e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:15:06   Log-Likelihood:            -1.6230e+05
# No. Observations:               20220   AIC:                         3.246e+05
# Df Residuals:                   20218   BIC:                         3.246e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -6.5735      6.407     -1.026      0.305     -19.133       5.986
# ...

# %%
# 경사도에 따라 나눈 총시간 ~ 왕복거리의 상관관계를 파악한다
# 몇개의 이상치를 빼면 특정 회귀식으로 0.9이상의 확률로 해당 자료를 설명할 수 있다.
# 경사도 0이상 10미만의 데이터로 처리한 결과

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols, glm
import scipy as sp

# %%
my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[(df.경사도>=0)&(df.경사도<10)]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 9.213e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        17:02:31   Log-Likelihood:                -44718.
# No. Observations:                6647   AIC:                         8.944e+04
# Df Residuals:                    6645   BIC:                         8.945e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4930      2.867      1.567      0.117      -1.127      10.113
# ...

# %%
my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[(df.경사도>=10)&(df.경사도<15)]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 3.588e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:16:50   Log-Likelihood:                -24769.
# No. Observations:                3668   AIC:                         4.954e+04
# Df Residuals:                    3666   BIC:                         4.956e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.6178      4.182      3.495      0.000       6.418      22.817
# ...

# %%
my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[(df.경사도>=15)&(df.경사도<20)]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 6.498e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:16:57   Log-Likelihood:                -20598.
# No. Observations:                3298   AIC:                         4.120e+04
# Df Residuals:                    3296   BIC:                         4.121e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.1074      2.763      4.020      0.000       5.689      16.525
# ...

# %%
my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[(df.경사도>=20)&(df.경사도<25)]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.180e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:17:00   Log-Likelihood:                -16507.
# No. Observations:                2738   AIC:                         3.302e+04
# Df Residuals:                    2736   BIC:                         3.303e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.0583      2.479      3.654      0.000       4.197      13.919
# ...

# %%
my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[(df.경사도>=25)&(df.경사도<30)]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 2.715e+05
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:17:03   Log-Likelihood:                -11370.
# No. Observations:                1921   AIC:                         2.274e+04
# Df Residuals:                    1919   BIC:                         2.276e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.4457      2.718      3.108      0.002       3.116      13.776
# ...

# %%
# 30이상으로 더 세부적으로 나눌 수 있지만 데이터 형태가 비슷해 보이므로 그냥 처리함

my_fml = '왕복거리 ~ 총시간'
lm = ols(my_fml, data = df[df.경사도>=30]).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   왕복거리   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                 4.980e+04
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):               0.00
# Time:                        16:17:04   Log-Likelihood:                -12588.
# No. Observations:                1948   AIC:                         2.518e+04
# Df Residuals:                    1946   BIC:                         2.519e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.6964      4.574      2.338      0.019       1.725      19.667
# ...

# %%
col_idx1 = ['구간_거리','시작_표고','끝_표고값','경사도']

# %%
train2 = df[col_idx1]

# %%
x1, x2, y1, y2 = train_test_split(train2,df.평균속력,test_size=0.2,random_state=42)

# %%
print(x1.shape)
print(x2.shape)
print(y1.shape)
print(y2.shape)
# Out:
# (16176, 4)
# (4044, 4)
# (16176,)
# (4044,)

# %%
train_model2 = DecisionTreeRegressor()

# %%
train_model2.fit(x1,y1)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred2 = train_model2.predict(x2)
y_pred2
# Out:
# array([49.        , 42.34042553, 27.16666667, ..., 60.82352941,
#        33.        , 41.31707317])

# %%
train_model2.score(x2,y2)
# Out:
# -0.7326764385502509

# %%
my_fml = '평균속력 ~ 경사도'
lm = ols(my_fml, data = df).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   평균속력   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     24.95
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           5.93e-07
# Time:                        16:45:36   Log-Likelihood:            -1.1382e+05
# No. Observations:               20220   AIC:                         2.276e+05
# Df Residuals:                   20218   BIC:                         2.277e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     47.8243      0.486     98.333      0.000      46.871      48.778
# ...

# %%
df[df.구간_거리>300]
# Out:
#       구간_거리  구간_상행  구간_하행  구간_난이도   시작_표고   끝_표고값     고도차        경사도  총시간  \
# 0     21755    422    296     1.0   680.0   664.0    16.0   0.073546  718
# 1     16640    323    226     1.0   756.0   766.0    10.0   0.060096  549
# 2     15399    299    209     1.0   661.0   540.0   121.0   0.785765  508
# 3     14689    285    200     1.0   523.0   517.0     6.0   0.040847  485
# 4     12629    245    172     1.0   239.0   231.0     8.0   0.063346  417
# 5     10761    209    146     1.0   929.0   746.0   183.0   1.700585  355
# 6     10627    206    144     2.0   571.0   561.0    10.0   0.094100  350
# 7     10296    200    140     2.0  1107.0  1097.0    10.0   0.097125  340
# 8      9730    219    153     1.0    16.0  1084.0  1068.0  10.976362  372
# 9      9621    187    131     1.0   628.0   310.0   318.0   3.305270  318
# 10     9523    185    129     2.0   363.0   275.0    88.0   0.924079  314
# 11     9503    184    129     1.0   264.0   461.0   197.0   2.073030  313
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Users/user/Desktop/경기도 빅데이터 자료/화이팅하조 팀프로젝트/산이름_위경도.csv",engine='python',encoding="UTF-8")

# %%
df.head()
# Out:
#   mountain                                            lat_lng
# 0     개화산0  [(126.817408155, 37.5823769479), (126.81732350...
# 1     개화산1  [(126.818800763, 37.5802651501), (126.81880340...
# 2     개화산2  [(126.81815665, 37.5804578707), (126.8181548, ...
# 3     개화산3  [(126.817194901, 37.579431931), (126.817294636...
# 4     개화산4  [(126.818800763, 37.5802651501), (126.81879991...

# %%
float(df.lat_lng[0].strip('[]').split(',')[2].strip(' ').strip('()'))
# Out:
# 126.817323508

# %%
lat = []
lng = []
for j in range(len(df.lat_lng[0].strip('[]').split(','))):
        if j%2==0:
            lat.append(float(df.lat_lng[0].strip('[]').split(',')[j].strip(' ').strip('()')))
        else:
            lng.append(float(df.lat_lng[0].strip('[]').split(',')[j].strip(' ').strip('()')))

# %%
'''lat = []
lng = []
lat_list=[]
lng_list=[]
for i in range(len(df.lat_lng)):
    for j in range(len(df.lat_lng[i].strip('[]').split(','))):
        if j%2==0:
            lat.append(float(df.lat_lng[i].strip('[]').split(',')[j].strip('()')))
        else:
            lng.append(float(df.lat_lng[i].strip('[]').split(',')[j].strip('()')))
    lat_list.append(lat)
    lng_list.append(lng)
    lat=[]
    lng=[]'''
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-94dd2dce8014> in <module>()
#       6     for j in range(len(df.lat_lng[i])):
#       7         lat.append(df.lat_lng[i][j][0])
# ----> 8         lng.append(df.lat_lng[i][j][1])
#       9         lat_list.append(lat)
#      10         lng_list.append(lng)
#
# IndexError: string index out of range

# %%
lat
# Out:
# [126.817408155,
#  126.817323508,
#  126.817294188,
#  126.817276465,
#  126.817268143,
#  126.817260368,
#  126.817253338,
#  126.817247311,
#  126.817242628,
#  126.817238867,
#  126.817235774,
#  126.817233159,
#  126.817230876,
#  126.817223097,
#  126.817218948,
#  126.817216517,
#  126.817213691,
#  126.817210309,
#  126.817206163,
#  126.817200986,
#  126.817194163,
#  126.817186207,
#  126.81717743,
#  126.817168064,
#  126.817158285,
#  126.817137963,
#  126.817106613,
#  126.81692756,
#  126.816896404,
#  126.816876407,
#  126.816866896,
#  126.816857903,
#  126.816849636,
#  126.816842372,
#  126.816836379,
#  126.816831385,
#  126.816827121,
#  126.816823385,
#  126.816816927,
#  126.816811209,
#  126.816797509,
#  126.816791326,
#  126.816787758,
#  126.816783648,
#  126.816778731,
#  126.816771715,
#  126.816760771,
#  126.816747338,
#  126.816731572,
#  126.816714557,
#  126.816697361,
#  126.816681029,
#  126.81666659,
#  126.816644931]

# %%
lng
# Out:
# [37.5823769479,
#  37.5822814823,
#  37.5822474569,
#  37.5822254927,
#  37.5822143491,
#  37.5822030416,
#  37.5821915108,
#  37.5821796795,
#  37.5821678867,
#  37.582155818,
#  37.582143549,
#  37.582131137,
#  37.5821186258,
#  37.5820681853,
#  37.5820430609,
#  37.5820306159,
#  37.5820183004,
#  37.5820061666,
#  37.5819942826,
#  37.5819827357,
#  37.5819709692,
#  37.5819595728,
#  37.5819484453,
#  37.58193751,
#  37.58192671,
#  37.581905359,
#  37.5818736159,
#  37.5816942041,
#  37.5816623838,
#  37.5816408931,
#  37.5816299739,
#  37.5816188703,
#  37.5816075085,
#  37.5815957901,
#  37.5815837267,
#  37.5815713081,
#  37.5815586285,
#  37.5815457592,
#  37.5815196526,
#  37.5814932746,
#  37.5814272203,
#  37.5814013006,
#  37.5813886696,
#  37.5813764147,
#  37.5813647216,
#  37.5813534921,
#  37.5813428061,
#  37.5813341456,
#  37.5813266675,
#  37.5813202999,
#  37.5813149832,
#  37.5813106736,
#  37.5813073396,
#  37.5813028496]

# %%
df1 = pd.DataFrame({'lat':lat,'lng':lng})

# %%
df1.head(10)
# Out:
#           lat        lng
# 0  126.817408  37.582377
# 1  126.817324  37.582281
# 2  126.817294  37.582247
# 3  126.817276  37.582225
# 4  126.817268  37.582214
# 5  126.817260  37.582203
# 6  126.817253  37.582192
# 7  126.817247  37.582180
# 8  126.817243  37.582168
# 9  126.817239  37.582156

# %%
df1.to_csv("개화산0.csv",index=False)
